# %%
# 1. Scrape data form YT videos
# 2. Scrape stats from channels
# 3. Download thumbnails
# 4. Download videos
# 5. Run a feature extractor over thumbnails
# 6. Run a feature extractor over videos (video and audio)
# 7. Create a preprocessors and dataloader for all data
# 8. Create the regression model
# 9. Train the model
# 10. Test the model

# %%
import pandas as pd

# %%
video_data_file = 'data/yt_video_data.csv'
channel_data_file = 'data/yt_channel_data.csv'

video_df = pd.read_csv(video_data_file, index_col=0)
channel_df = pd.read_csv(channel_data_file, index_col=0)

# %%
print(video_df.columns.tolist())
print(channel_df.columns.tolist())
# Out:
# ['thumbnail_link', 'view_count', 'date', 'video_title', 'video_description', 'subscriber_count', 'likes', 'scrape_date', 'channel_name', 'channel_link', 'video_url']
# ['channel_name', 'channel_url', 'title', 'upload_date', 'view_count', 'scrape_date']

# %%
len(video_df['channel_name'].unique())
# Out:
# 8226

# %%
"""
The program makes the necessary imports, then creates an image feature extractor.
The model used for feature extraction is a pretrained resnet50 model.
Torchfx is used to make the output of the model the 2nd and 4th layer outputs of the resnet model.
"""

import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
import tqdm

from models import ImageFeatureExtractor

DEVICE = 'cuda:0'

# %%
"""
Creates a dataset of all the images in the "thumbnails" folder.
The ImageFolder class is not used because there are not classes,
rather, the folder directly contains all the images.
"""
import os
from PIL import Image

# # Source: https://discuss.pytorch.org/t/how-to-resize-and-pad-in-a-torchvision-transforms-compose/71850
# class SquarePad:
#     def __call__(self, image):
#         max_wh = max(image.size)
#         p_left, p_top = [(max_wh - s) // 2 for s in image.size]
#         p_right, p_bottom = [max_wh - (s+pad) for s, pad in zip(image.size, [p_left, p_top])]
#         padding = (p_left, p_top, p_right, p_bottom)
#         return F.pad(image, padding, 0, 'constant')

# TODO: Try redoing this with cropping or square padding
img_transform = transforms.Compose([
        # transforms.Resize(256),
        # transforms.CenterCrop(224),
        # SquarePad(),
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(
            mean=[0.485, 0.456, 0.406],
            std=[0.229, 0.224, 0.225])
    ])

class ImageDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.img_names = os.listdir(self.root_dir)

    def __len__(self):
        return len(self.img_names)

    def __getitem__(self, idx):
        img_name = self.img_names[idx]
        img_path = os.path.join(self.root_dir, img_name)
        img = Image.open(img_path)
        if self.transform:
            img = self.transform(img)
        return img_name, img

# %%
tds = ImageDataset(root_dir='thumbnails', transform=img_transform)
# Create a dataloader for the images
tdl = DataLoader(tds, batch_size=2, shuffle=False)
a = next(tdl.__iter__())

# %%
a[1].shape
# Out:
# torch.Size([2, 3, 224, 224])

# %%
fe = ImageFeatureExtractor()
fe(a[1]).shape
# Out:
# torch.Size([2, 2048])

# %%
# Add thumbnail embeddings to the video dataframe
thumbnail_dataset = ImageDataset(root_dir='thumbnails', transform=img_transform)
thumbnail_loader = DataLoader(tds, batch_size=64, shuffle=False)

feature_extractor = ImageFeatureExtractor().to(DEVICE)

thumbnail_features = {}
print('Generating thumbnail features...')
for img_names, imgs in tqdm.tqdm(thumbnail_loader):
    imgs = imgs.to(DEVICE)
    all_features = feature_extractor(imgs)
    all_features = all_features.cpu().detach().numpy()
    for img_name, img_features in zip(img_names, all_features):
        img_idx = int(img_name.split('.')[0])
        thumbnail_features[img_idx] = img_features
# Out:
# Generating thumbnail features...
# 100%|██████████| 280/280 [01:08<00:00,  4.06it/s]

# %%
video_df['thumbnail_embedding'] = video_df.apply(lambda x: thumbnail_features.get(x.name), axis=1)

# %%
print(video_df.columns)
print(channel_df.columns)
# Out:
# Index(['thumbnail_link', 'view_count', 'date', 'video_title',
#        'video_description', 'subscriber_count', 'likes', 'scrape_date',
#        'channel_name', 'channel_link', 'video_url'],
#       dtype='object')
# Index(['channel_name', 'channel_link', 'title', 'upload_date', 'view_count',
#        'scrape_date'],
#       dtype='object')

# %%
video_df.shape
# Out:
# (26005, 11)

# %%
# Data prep steps:
# 1. Generate features for the video df thumbnails
# 2. Change the channel df column names
# 3. Merge the video and channel dfs
# 4. Drop NA rows and then drop rows with duplicate video urls
# 5. Save the new dataframe

# %%
video_df

# %%
final_df =

# %%
pd.merge(video_df, channel_df, how='left', on=['channel_name', 'channel_link'])
# Out:
#                                           thumbnail_link  view_count_x  \
# 0                                                    NaN        412161
# 1      https://i.ytimg.com/vi/LZzH9VqfFEU/hqdefault.j...        412161
# 2                                                    NaN      14837155
# 3                                                    NaN      25240078
# 4                                                    NaN        259512
# ...                                                  ...           ...
# 26000  https://i.ytimg.com/vi/Czg_9C7gw0o/hqdefault.j...       7523088
# 26001  https://i.ytimg.com/vi/xI8lLpYtQ6M/hqdefault.j...       3289008
# 26002  https://i.ytimg.com/vi/KElkR9qz-f4/hqdefault.j...       1529396
# 26003  https://i.ytimg.com/vi/QlmlqAW0cUQ/hqdefault.j...       3354281
# 26004  https://i.ytimg.com/vi/4VpY6lGOPuc/hqdefault.j...        112116
#
#                date                                        video_title  \
# 0      Dec 12, 2021  Giants vs. Chargers Week 14 Highlights | NFL 2021
# 1      Dec 12, 2021  Giants vs. Chargers Week 14 Highlights | NFL 2021
# 2      May 22, 2021                              Math Has a Fatal Flaw
# 3      Oct 31, 2012               Skydiving into the Blue Hole, Belize
# 4       Dec 2, 2021                   Top 10 Worst Video Games of 2021
# ...             ...                                                ...
# 26000  Jun 25, 2019  Waking up as a meme-hero | Andras Arato | TEDx...
# 26001  Jun 22, 2017  Is Social Media Hurting Your Mental Health? | ...
# 26002  Dec 11, 2021     I Survived 2,600 Days in HARDCORE Minecraft...
# 26003   Oct 5, 2015  Mind is Everything | Dr. David Hendricks | TED...
# 26004  Dec 12, 2021  ALIENS Are in BTD 6?! (Huge Bloons TD 6 Mod - ...
#
#                                        video_description  subscriber_count  \
# 0      The New York Giants take on the Los Angeles Ch...           8520000
# 1      The New York Giants take on the Los Angeles Ch...           8520000
# 2      Not everything that is true can be proven. Thi...          11100000
# 3      http://yogaFLIGHT.com\n\nThe ultimate skydive ...             46600
# 4      These games were undoubtedly the worst to rele...          24100000
# ...                                                  ...               ...
# 26000  What would you feel if one day you wake up and...          33400000
# 26001  Scrolling through our social media feeds feels...          33400000
# 26002  2,500 DAYS HARDCORE VIDEO: https://youtu.be/F_...           1180000
# 26003  NOTE FROM TED: Do not look to this talk for me...          33400000
# 26004  Want FREE tickets to Japan? Use my code: TEWTI...           1180000
#
#           likes scrape_date_x   channel_name  \
# 0        4884.0  Dec 14, 2021            NFL
# 1        4884.0  Dec 14, 2021            NFL
# 2      542231.0  Dec 14, 2021     Veritasium
# 3      258377.0  Dec 14, 2021     yogaFLIGHT
# 4        5746.0  Dec 14, 2021  WatchMojo.com
# ...         ...           ...            ...
# 26000  405913.0  Dec 14, 2021     TEDx Talks
# 26001   93058.0  Dec 14, 2021     TEDx Talks
# 26002    5926.0  Dec 14, 2021          SB737
# 26003   22285.0  Dec 14, 2021     TEDx Talks
# 26004    5926.0  Dec 14, 2021         Tewtiy
#
#                                             channel_link  \
# 0      https://www.youtube.com/channel/UCDVYQ4Zhbm3S2...
# 1      https://www.youtube.com/channel/UCDVYQ4Zhbm3S2...
# 2      https://www.youtube.com/channel/UCHnyfMqiRRG1u...
# 3      https://www.youtube.com/channel/UCbmzgkvMl7SHK...
# 4      https://www.youtube.com/channel/UCaWd5_7JhbQBe...
# ...                                                  ...
# 26000  https://www.youtube.com/channel/UCsT0YIqwnpJCM...
# 26001  https://www.youtube.com/channel/UCsT0YIqwnpJCM...
# 26002  https://www.youtube.com/channel/UCh_qU1GUf4FcN...
# 26003  https://www.youtube.com/channel/UCsT0YIqwnpJCM...
# 26004  https://www.youtube.com/channel/UCh_qU1GUf4FcN...
#
#                                          video_url  \
# 0      https://www.youtube.com/watch?v=ziXPgr8hiLM
# 1      https://www.youtube.com/watch?v=LZzH9VqfFEU
# 2      https://www.youtube.com/watch?v=HeQX2HjkcNo
# 3      https://www.youtube.com/watch?v=jmZ0fJC5lwQ
# 4      https://www.youtube.com/watch?v=EGWBKvB098Q
# ...                                            ...
# 26000  https://www.youtube.com/watch?v=Czg_9C7gw0o
# 26001  https://www.youtube.com/watch?v=xI8lLpYtQ6M
# 26002  https://www.youtube.com/watch?v=KElkR9qz-f4
# 26003  https://www.youtube.com/watch?v=QlmlqAW0cUQ
# 26004  https://www.youtube.com/watch?v=4VpY6lGOPuc
#
#                                                    title  \
# 0      ("How Rodney McLeod's 'Game Changers' Provides...
# 1      ("How Rodney McLeod's 'Game Changers' Provides...
# 2      ('The Snowflake Mystery', "Most People Don't K...
# 3      ('Toronto: Top 6 of the 6ix!', 'A yogaFLIGHT B...
# 4      ('On This Day In 2000 | RetroVideo', 'Top 10 S...
# ...                                                  ...
# 26000                                                NaN
# 26001                                                NaN
# 26002                                                NaN
# 26003                                                NaN
# 26004  ('Bananas BOOST Monkeys?! (Blessing Towers Wit...
#
#                                              upload_date  \
# 0      ('7 hours ago', '12 hours ago', 'Streamed 14 h...
# 1      ('7 hours ago', '12 hours ago', 'Streamed 14 h...
# 2      ('2 weeks ago', '2 weeks ago', '3 weeks ago', ...
# 3      ('3 years ago', '7 years ago', '7 years ago', ...
# 4      ('1 hour ago', '6 hours ago', '9 hours ago', '...
# ...                                                  ...
# 26000                                                NaN
# 26001                                                NaN
# 26002                                                NaN
# 26003                                                NaN
# 26004  ('9 hours ago', '1 day ago', '2 days ago', '3 ...
#
#                                             view_count_y scrape_date_y
# 0      (4300, 47000, 51000, 81000, 9900, 9900, 123000...  Dec 15, 2021
# 1      (4300, 47000, 51000, 81000, 9900, 9900, 123000...  Dec 15, 2021
# 2      (5700000, 10000000, 10000000, 9600000, 5800000...  Dec 15, 2021
# 3      (3700, 3000, 14000, 1100, 3700, 14000, 16000, ...  Dec 15, 2021
# 4      (2300, 18000, 32000, 24000, 40000, 16000, 1900...  Dec 15, 2021
# ...                                                  ...           ...
# 26000                                                NaN           NaN
# 26001                                                NaN           NaN
# 26002                                                NaN           NaN
# 26003                                                NaN           NaN
# 26004  (55000, 130000, 119000, 157000, 154000, 228000...  Dec 15, 2021
#
# [26005 rows x 15 columns]

# %%
len(video_df.dropna().drop_duplicates(subset=['thumbnail_link', 'video_title']))
# Out:
# 16058

# %%
thumbnail_features
# Out:
# {1: array([0.3192735 , 0.68836987, 0.7462309 , ..., 0.79271585, 0.24264106,
#         0.02141257], dtype=float32),
#  10: array([0.11920096, 0.26325592, 0.6720083 , ..., 0.758535  , 0.34693724,
#         0.06105711], dtype=float32),
#  100: array([0.03960769, 0.692111  , 0.26814315, ..., 0.41287103, 1.0050873 ,
#         0.11512326], dtype=float32),
#  10000: array([0.65285236, 0.78685135, 1.1871752 , ..., 0.3095802 , 0.30660123,
#         0.15129216], dtype=float32),
#  10001: array([0.76707625, 0.77118087, 0.35248336, ..., 0.32322475, 0.05263793,
#         0.50666314], dtype=float32),
#  10002: array([0.43951142, 0.21792398, 0.3948624 , ..., 0.23010172, 0.461626  ,
#         0.8046133 ], dtype=float32),
#  10003: array([0.2955636 , 0.15273872, 0.46796793, ..., 0.18608952, 0.35784912,
#         0.2490325 ], dtype=float32),
#  10004: array([0.8736051 , 0.08869307, 0.8069382 , ..., 0.560225  , 0.5274395 ,
#         0.18770084], dtype=float32),
#  10005: array([0.6603811 , 0.13746347, 0.44977596, ..., 0.70550156, 0.02760438,
#         0.1735594 ], dtype=float32),
#  10006: array([0.29745954, 0.65481055, 0.55068624, ..., 0.9293888 , 0.5974865 ,
#         0.18224965], dtype=float32),
#  10007: array([0.29060185, 0.33882335, 1.043743  , ..., 0.19887462, 0.22644393,
#         0.36470553], dtype=float32),
#  10008: array([0.4053089 , 0.37845477, 0.40790537, ..., 0.        , 0.35611585,
#         0.3352047 ], dtype=float32),
#  10009: array([0.18752584, 0.07358674, 0.08924351, ..., 0.21163784, 0.2378998 ,
#         0.04764647], dtype=float32),
#  1001: array([0.17715475, 1.5665649 , 0.53626317, ..., 0.30550712, 0.31863478,
#         0.2969881 ], dtype=float32),
#  10010: array([0.07134213, 0.01795463, 0.04523474, ..., 0.20451812, 0.9948725 ,
#         0.04663409], dtype=float32),
#  10011: array([0.9720683 , 0.2659969 , 0.45876694, ..., 0.06231665, 0.10928216,
#         0.28205672], dtype=float32),
#  10012: array([0.2850476 , 0.7827989 , 0.15441637, ..., 0.22545594, 0.19357875,
#         0.3839123 ], dtype=float32),
#  10013: array([0.44514737, 0.33797672, 0.24618518, ..., 0.24518773, 0.4108227 ,
#         0.10128719], dtype=float32),
#  10014: array([0.56505567, 0.5843863 , 0.34926823, ..., 0.0092072 , 0.10613175,
#         0.1638054 ], dtype=float32),
#  10015: array([0.10177431, 0.9182129 , 0.1035817 , ..., 0.21039626, 0.19016923,
#         0.30712226], dtype=float32),
#  10016: array([0.180915  , 0.9759473 , 0.77963257, ..., 0.47668704, 0.81916684,
#         0.28634974], dtype=float32),
#  10017: array([0.04354294, 0.06846345, 0.39403322, ..., 0.25689346, 0.1349808 ,
#         0.00652548], dtype=float32),
#  10018: array([0.        , 0.38390887, 0.2529118 , ..., 0.42633298, 0.09116186,
#         0.3535923 ], dtype=float32),
#  10019: array([0.05984979, 0.11463729, 0.0904619 , ..., 0.36250904, 0.8214518 ,
#         0.33216304], dtype=float32),
#  1002: array([1.1164267 , 0.83983594, 0.27299154, ..., 0.12594254, 0.33799773,
#         0.28403535], dtype=float32),
#  10020: array([0.27760172, 0.04384281, 0.25768906, ..., 0.01216909, 0.7644335 ,
#         0.23865627], dtype=float32),
#  10021: array([0.11037338, 0.42756164, 0.31019402, ..., 0.13259646, 1.0890467 ,
#         0.7204904 ], dtype=float32),
#  10022: array([0.29419434, 1.0693339 , 0.07925052, ..., 0.14826609, 0.15366821,
#         0.25306043], dtype=float32),
#  10023: array([0.2368732 , 0.5002107 , 0.83639324, ..., 0.7870846 , 1.0562266 ,
#         0.75264925], dtype=float32),
#  10025: array([0.129089  , 0.6778497 , 0.23124638, ..., 0.17879272, 0.02920935,
#         1.3419987 ], dtype=float32),
#  10026: array([0.916286  , 0.59353817, 1.3623031 , ..., 0.27418223, 0.45025337,
#         0.6146901 ], dtype=float32),
#  10027: array([0.65543115, 1.3349952 , 0.23396002, ..., 0.08687146, 0.20150849,
#         0.48658448], dtype=float32),
#  10028: array([0.41052863, 1.1582963 , 0.32878345, ..., 0.04132385, 0.10775882,
#         0.424949  ], dtype=float32),
#  10029: array([1.1524572 , 0.94004554, 1.3701726 , ..., 0.083955  , 0.39778677,
#         1.331371  ], dtype=float32),
#  1003: array([0.0991521 , 0.06349295, 0.77127326, ..., 0.2444274 , 0.2539876 ,
#         0.10314348], dtype=float32),
#  10030: array([0.4740071 , 0.88509554, 0.17480096, ..., 0.37001246, 0.2802353 ,
#         0.26888195], dtype=float32),
#  10031: array([0.19060174, 0.11852987, 0.03231875, ..., 0.20434438, 0.4740598 ,
#         0.13984703], dtype=float32),
#  10032: array([0.00681791, 0.7631054 , 0.10453078, ..., 0.08392038, 0.00517845,
#         0.11082834], dtype=float32),
#  10033: array([0.13976239, 0.10783041, 0.59470814, ..., 0.05338988, 0.1187254 ,
#         0.47508526], dtype=float32),
#  10034: array([0.13731545, 0.8024071 , 1.4589477 , ..., 0.2565045 , 0.08231284,
#         0.18984179], dtype=float32),
#  10035: array([0.30725017, 0.25545555, 0.38737974, ..., 0.6918427 , 0.4647448 ,
#         0.13359225], dtype=float32),
#  10036: array([0.56303006, 0.36480728, 0.97609675, ..., 0.25432837, 0.9895991 ,
#         0.49001026], dtype=float32),
#  10037: array([0.28823683, 0.23426297, 0.55345815, ..., 0.64120793, 0.535952  ,
#         0.11862184], dtype=float32),
#  10038: array([0.45464367, 0.61858165, 0.61841977, ..., 0.5986636 , 0.78038657,
#         0.4074426 ], dtype=float32),
#  10039: array([0.11131603, 1.5779369 , 0.43961933, ..., 0.63689625, 0.8853274 ,
#         0.16875301], dtype=float32),
#  1004: array([0.18686856, 1.5140729 , 0.41209528, ..., 0.03945634, 0.3490149 ,
#         1.0712553 ], dtype=float32),
#  10040: array([0.50553596, 1.0768789 , 1.9034622 , ..., 0.5296398 , 1.0332909 ,
#         0.11151582], dtype=float32),
#  10041: array([0.07508177, 0.22930978, 0.15089041, ..., 1.0625087 , 0.1789638 ,
#         0.02041517], dtype=float32),
#  10042: array([0.5187689 , 0.92152226, 0.29927927, ..., 0.1220687 , 0.14316085,
#         0.01435861], dtype=float32),
#  10043: array([0.04099509, 0.1086621 , 0.34802362, ..., 0.5513563 , 0.9756656 ,
#         0.3887329 ], dtype=float32),
#  10044: array([5.2641302e-02, 5.5499222e-05, 6.1262408e-03, ..., 5.5682763e-02,
#         5.9750184e-02, 5.7400537e-01], dtype=float32),
#  10045: array([1.3611002 , 0.43785986, 1.107875  , ..., 0.45997953, 2.1076784 ,
#         0.5018306 ], dtype=float32),
#  10046: array([0.17136325, 0.33871624, 0.21247482, ..., 0.23949623, 0.3211154 ,
#         0.48737156], dtype=float32),
#  10047: array([0.18990605, 0.04998117, 0.30501473, ..., 0.39746404, 0.08489269,
#         0.22447418], dtype=float32),
#  10048: array([0.0686231 , 0.9430476 , 0.22875556, ..., 0.20733556, 0.4164439 ,
#         0.20908546], dtype=float32),
#  10049: array([0.38049316, 0.02364441, 0.01654307, ..., 0.1772417 , 0.15787975,
#         0.29323512], dtype=float32),
#  1005: array([0.38645187, 0.38552856, 0.20194638, ..., 0.44700342, 1.4057533 ,
#         0.47393572], dtype=float32),
#  10050: array([0.3293055 , 1.1465365 , 1.4628265 , ..., 0.30202445, 0.9600762 ,
#         0.27761242], dtype=float32),
#  10051: array([0.5805387 , 0.1680732 , 0.08637321, ..., 0.2627881 , 0.0809229 ,
#         0.11611367], dtype=float32),
#  10052: array([0.31274056, 0.28135908, 0.01056441, ..., 0.25873992, 0.44194844,
#         0.06789104], dtype=float32),
#  10053: array([0.04912854, 0.19429907, 0.32196227, ..., 0.32491183, 0.32155105,
#         0.1877546 ], dtype=float32),
#  10054: array([0.16087836, 2.1505616 , 0.05491067, ..., 0.06587552, 0.18438327,
#         0.16256694], dtype=float32),
#  10055: array([0.3195488 , 1.3946804 , 1.0988349 , ..., 0.2982524 , 0.21628967,
#         0.14827062], dtype=float32),
#  10056: array([0.6664213 , 0.93416756, 0.16007155, ..., 0.55908364, 0.02691835,
#         0.3137912 ], dtype=float32)}
